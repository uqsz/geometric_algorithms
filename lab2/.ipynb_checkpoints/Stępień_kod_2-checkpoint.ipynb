# %% [markdown]
# # Konfiguracja narzędzia graficznego

# %%
# Narzędzie jest oparte o kilka zewnętrznych bibliotek, które potrzebujemy najpierw zaimportować.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections as mcoll
import matplotlib.colors as mcolors
from matplotlib.widgets import Button
import json as js

# Parametr określający jak blisko (w odsetku całego widocznego zakresu) punktu początkowego 
# wielokąta musimy kliknąć, aby go zamknąć.
TOLERANCE = 0.15

def dist(point1, point2):
    return np.sqrt(np.power(point1[0] - point2[0], 2) + np.power(point1[1] - point2[1], 2))

# Klasa ta trzyma obecny stan wykresu oraz posiada metody, które mają zostać wykonane
# po naciśnięciu przycisków.
class _Button_callback(object):
    def __init__(self, scenes):
        self.i = 0
        self.scenes = scenes
        self.adding_points = False
        self.added_points = []
        self.adding_lines = False
        self.added_lines = []
        self.adding_rects = False
        self.added_rects = []

    def set_axes(self, ax):
        self.ax = ax
        
    # Metoda ta obsługuje logikę przejścia do następnej sceny.
    def next(self, event):
        self.i = (self.i + 1) % len(self.scenes)
        self.draw(autoscaling = True)

    # Metoda ta obsługuje logikę powrotu do poprzedniej sceny.
    def prev(self, event):
        self.i = (self.i - 1) % len(self.scenes)
        self.draw(autoscaling = True)
        
    # Metoda ta aktywuje funkcję rysowania punktów wyłączając równocześnie rysowanie 
    # odcinków i wielokątów.
    def add_point(self, event):
        self.adding_points = not self.adding_points
        self.new_line_point = None
        if self.adding_points:
            self.adding_lines = False
            self.adding_rects = False
            self.added_points.append(PointsCollection([]))
            
    # Metoda ta aktywuje funkcję rysowania odcinków wyłączając równocześnie
    # rysowanie punktów i wielokątów.     
    def add_line(self, event):   
        self.adding_lines = not self.adding_lines
        self.new_line_point = None
        if self.adding_lines:
            self.adding_points = False
            self.adding_rects = False
            self.added_lines.append(LinesCollection([]))

    # Metoda ta aktywuje funkcję rysowania wielokątów wyłączając równocześnie
    # rysowanie punktów i odcinków.
    def add_rect(self, event):
        self.adding_rects = not self.adding_rects
        self.new_line_point = None
        if self.adding_rects:
            self.adding_points = False
            self.adding_lines = False
            self.new_rect()
    
    def new_rect(self):
        self.added_rects.append(LinesCollection([]))
        self.rect_points = []
        
    # Metoda odpowiedzialna za właściwą logikę rysowania nowych elementów. W
    # zależności od włączonego trybu dodaje nowe punkty, początek, koniec odcinka
    # lub poszczególne wierzchołki wielokąta. Istnieje ciekawa logika sprawdzania
    # czy dany punkt jest domykający dla danego wielokąta. Polega ona na tym, że
    # sprawdzamy czy odległość nowego punktu od początkowego jest większa od
    # średniej długości zakresu pomnożonej razy parametr TOLERANCE.   
    def on_click(self, event):
        if event.inaxes != self.ax:
            return
        new_point = (event.xdata, event.ydata)
        if self.adding_points:
            self.added_points[-1].add_points([new_point])
            self.draw(autoscaling = False)
        elif self.adding_lines:
            if self.new_line_point is not None:
                self.added_lines[-1].add([self.new_line_point, new_point])
                self.new_line_point = None
                self.draw(autoscaling = False)
            else:
                self.new_line_point = new_point
        elif self.adding_rects:
            if len(self.rect_points) == 0:
                self.rect_points.append(new_point)
            elif len(self.rect_points) == 1:
                self.added_rects[-1].add([self.rect_points[-1], new_point])
                self.rect_points.append(new_point)
                self.draw(autoscaling = False)
            elif len(self.rect_points) > 1:
                if dist(self.rect_points[0], new_point) < (np.mean([self.ax.get_xlim(), self.ax.get_ylim()])*TOLERANCE):
                    self.added_rects[-1].add([self.rect_points[-1], self.rect_points[0]])
                    self.new_rect()
                else:    
                    self.added_rects[-1].add([self.rect_points[-1], new_point])
                    self.rect_points.append(new_point)
                self.draw(autoscaling = False)
    
    # Metoda odpowiedzialna za narysowanie całego wykresu. Warto zauważyć,
    # że zaczyna się ona od wyczyszczenia jego wcześniejszego stanu. Istnieje w
    # niej nietrywialna logika zarządzania zakresem wykresu, tak żeby, w zależności
    # od ustawionego parametru autoscaling, uniknąć sytuacji, kiedy dodawanie
    # nowych punktów przy brzegu obecnie widzianego zakresu powoduje niekorzystne
    # przeskalowanie.
    def draw(self, autoscaling = True):
        if not autoscaling:
            xlim = self.ax.get_xlim()
            ylim = self.ax.get_ylim()
        self.ax.clear()
        for collection in (self.scenes[self.i].points + self.added_points):
            if len(collection.points) > 0:
                self.ax.scatter(*zip(*(np.array(collection.points))), **collection.kwargs)
        for collection in (self.scenes[self.i].lines + self.added_lines + self.added_rects):
            self.ax.add_collection(collection.get_collection())
        self.ax.autoscale(autoscaling)
        if not autoscaling:
            self.ax.set_xlim(xlim)
            self.ax.set_ylim(ylim)
        plt.draw()

# %%
# Klasa Scene odpowiada za przechowywanie elementów, które mają być
# wyświetlane równocześnie. Konkretnie jest to lista PointsCollection i
# LinesCollection.
class Scene:
    def __init__(self, points=[], lines=[]):
        self.points=points
        self.lines=lines

# Klasa PointsCollection gromadzi w sobie punkty jednego typu, a więc takie,
# które zostaną narysowane w takim samym kolorze i stylu. W konstruktorze
# przyjmuje listę punktów rozumianych jako pary współrzędnych (x, y). Parametr
# kwargs jest przekazywany do wywołania funkcji z biblioteki MatPlotLib przez
# co użytkownik może podawać wszystkie parametry tam zaproponowane.        
class PointsCollection:
    def __init__(self, points, **kwargs):
        self.points = points
        self.kwargs = kwargs
    
    def add_points(self, points):
        self.points = self.points + points

# Klasa LinesCollection podobnie jak jej punktowy odpowiednik gromadzi
# odcinki tego samego typu. Tworząc ją należy podać listę linii, gdzie każda
# z nich jest dwuelementową listą punktów – par (x, y). Parametr kwargs jest
# przekazywany do wywołania funkcji z biblioteki MatPlotLib przez co użytkownik
# może podawać wszystkie parametry tam zaproponowane.
class LinesCollection:
    def __init__(self, lines, **kwargs):
        self.lines = lines
        self.kwargs = kwargs
        
    def add(self, line):
        self.lines.append(line)
        
    def get_collection(self):
        return mcoll.LineCollection(self.lines, **self.kwargs)

# Klasa Plot jest najważniejszą klasą w całym programie, ponieważ agreguje
# wszystkie przygotowane sceny, odpowiada za stworzenie wykresu i przechowuje
# referencje na przyciski, dzięki czemu nie będą one skasowane podczas tzw.
# garbage collectingu.
class Plot:
    def __init__(self, scenes = [Scene()], points = [], lines = [], json = None):
        if json is None:
            self.scenes = scenes
            if points or lines:
                self.scenes[0].points = points
                self.scenes[0].lines = lines
        else:
            self.scenes = [Scene([PointsCollection(pointsCol) for pointsCol in scene["points"]], 
                                 [LinesCollection(linesCol) for linesCol in scene["lines"]]) 
                           for scene in js.loads(json)]
    
    # Ta metoda ma szczególne znaczenie, ponieważ konfiguruje przyciski i
    # wykonuje tym samym dość skomplikowaną logikę. Zauważmy, że konfigurując każdy
    # przycisk podajemy referencję na metodę obiektu _Button_callback, która
    # zostanie wykonana w momencie naciśnięcia.
    def __configure_buttons(self):
        plt.subplots_adjust(bottom=0.2)
        ax_prev = plt.axes([0.6, 0.05, 0.15, 0.075])
        ax_next = plt.axes([0.76, 0.05, 0.15, 0.075])
        ax_add_point = plt.axes([0.44, 0.05, 0.15, 0.075])
        ax_add_line = plt.axes([0.28, 0.05, 0.15, 0.075])
        ax_add_rect = plt.axes([0.12, 0.05, 0.15, 0.075])
        b_next = Button(ax_next, 'Następny')
        b_next.on_clicked(self.callback.next)
        b_prev = Button(ax_prev, 'Poprzedni')
        b_prev.on_clicked(self.callback.prev)
        b_add_point = Button(ax_add_point, 'Dodaj punkt')
        b_add_point.on_clicked(self.callback.add_point)
        b_add_line = Button(ax_add_line, 'Dodaj linię')
        b_add_line.on_clicked(self.callback.add_line)
        b_add_rect = Button(ax_add_rect, 'Dodaj figurę')
        b_add_rect.on_clicked(self.callback.add_rect)
        return [b_prev, b_next, b_add_point, b_add_line, b_add_rect]
    
    def add_scene(self, scene):
        self.scenes.append(scene)
    
    def add_scenes(self, scenes):
        self.scenes = self.scenes + scenes

    # Metoda toJson() odpowiada za zapisanie stanu obiektu do ciągu znaków w
    # formacie JSON.
    def toJson(self):
        return js.dumps([{"points": [np.array(pointCol.points).tolist() for pointCol in scene.points], 
                          "lines":[linesCol.lines for linesCol in scene.lines]} 
                         for scene in self.scenes])    
    
    # Metoda ta zwraca punkty dodane w trakcie rysowania.
    def get_added_points(self):
        if self.callback:
            return self.callback.added_points
        else:
            return None
    
    # Metoda ta zwraca odcinki dodane w trakcie rysowania.
    def get_added_lines(self):
        if self.callback:
            return self.callback.added_lines
        else:
            return None
        
    # Metoda ta zwraca wielokąty dodane w trakcie rysowania.
    def get_added_figure(self):
        if self.callback:
            return self.callback.added_rects
        else:
            return None
    
    # Metoda ta zwraca punkty, odcinki i wielokąty dodane w trakcie rysowania
    # jako scenę.
    def get_added_elements(self):
        if self.callback:
            return Scene(self.callback.added_points, self.callback.added_lines+self.callback.added_rects)
        else:
            return None
    
    # Główna metoda inicjalizująca wyświetlanie wykresu.
    def draw(self):
        plt.close()
        fig = plt.figure()
        self.callback = _Button_callback(self.scenes)
        self.widgets = self.__configure_buttons()
        ax = plt.axes(autoscale_on = False)
        self.callback.set_axes(ax)
        fig.canvas.mpl_connect('button_press_event', self.callback.on_click)
        plt.show()
        self.callback.draw()

# %% [markdown]
# # Rozwiązanie

# %% [markdown]
# ### Funkcje generujące zestawy danych

# %%
import random
from time import time

def gen_A(n,left,right,seed): #(liczba punktów, lewy koniec przedziału, prawy koniec przedziału)
    random.seed(seed) #ustalony seed, zmienić dla innych zestawów danych
    A=[]
    for i in range(n):
        x = random.uniform(left, right)
        y = random.uniform(left, right)
        A.append((x, y))
    return A

def gen_B(n,s,r,seed): #(liczba punktów, srodek okregu, promien okregu)
    random.seed(seed) #ustalony seed, zmienić dla innych zestawów danych
    B = []
    for i in range(0,n):
        a = (i/n)*(2*np.pi)
        x = np.cos(a)*r+s[0]
        y = np.sin(a)*r+s[1]
        B.append((x, y))
    return B

def gen_C(n,downLeft,upRight,seed): #(liczba punktów, lewy dolny wierzcholek prostokata, prawy gorny wierzcholek prostokata)
    random.seed(seed) #ustalony seed, zmienić dla innych zestawów danych
    C=[]
    for i in range(n):
        x = random.uniform(downLeft[0],upRight[0])
        y = random.uniform(downLeft[1],upRight[1])
        r=random.randint(0,3)
        if r==0:
            C.append((downLeft[0], y))
        elif r==1:
            C.append((upRight[0], y))
        elif r==2:
            C.append((x, downLeft[1]))
        elif r==3:
            C.append((x, upRight[1]))
    return C

def gen_D(n_side,n_axis,downLeft,upRight,seed): #(liczba punktów na boku, liczba punktow na przekatnych, lewy dolny wierzcholek prostokata, prawy gorny wierzcholek prostokata)
    random.seed(seed) #ustalony seed, zmienić dla innych zestawów danych
    D=[downLeft,upRight,(downLeft[0],upRight[1]),(upRight[0],downLeft[1])]
    for i in range(n_side):
        x = random.uniform(downLeft[0],upRight[0])
        D.append((x,downLeft[1]))
    for i in range(n_side):
        y = random.uniform(downLeft[1],upRight[1])
        D.append((downLeft[0],y))
    slp=(upRight[1]-downLeft[1])/(upRight[0]-downLeft[0])
    b=downLeft[1]-slp*downLeft[0]
    for i in range(n_axis):
        x = random.uniform(downLeft[0],upRight[0])
        D.append((x,slp*x+b))
    b=upRight[1]+slp*downLeft[0]
    for i in range(n_axis):
        x = random.uniform(downLeft[0],upRight[0])
        D.append((x,-slp*x+b))
    return D

# %% [markdown]
# # Wizualizacja zestawów danych

# %% [markdown]
# ### Wyznaczenie zestawów

# %%
A=gen_A(100,-100,100,10) #100
B=gen_B(100,(0,0),10,10) # 100
C=gen_C(100,(-10,-10),(10,10),11) # 100
D=gen_D(25,20,(0,0),(10,10),10) # 90

A_mod=gen_A(10**5,-10**3,10**3,123)
B_mod=gen_B(3*10**3,(-20,134),100,10234)
C_mod=gen_C(10**5,(-536,-120),(1045,102),11) 
D_mod=gen_D(10**4,10**4,(-240,-126),(2354,855),10)

# %% [markdown]
# ### Zestaw A

# %%
# %matplotlib notebook
Plot(points=[PointsCollection(A)]).draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw B

# %%
# %matplotlib notebook
Plot(points=[PointsCollection(B)]).draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw C

# %%
# %matplotlib notebook
Plot(points=[PointsCollection(C)]).draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw D

# %%
# %matplotlib notebook
Plot(points=[PointsCollection(D)]).draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Implementacja przydatnych funkcji

# %% [markdown]
# ### Obliczanie wyznacznika macierzy

# %%
def det(a,b,c): # (wspolrzedne a, wspolrzedne b, wspolrzedne c)
    matrix=[[a[0], a[1], 1], [b[0], b[1], 1], [c[0], c[1], 1]]
    return (matrix[0][0] * matrix[1][1] * matrix[2][2] + 
            matrix[1][0] * matrix[2][1] * matrix[0][2] + 
            matrix[2][0] * matrix[0][1] * matrix[1][2] - 
            matrix[2][0] * matrix[1][1] * matrix[0][2] - 
            matrix[1][0] * matrix[0][1] * matrix[2][2] - 
            matrix[0][0] * matrix[2][1] * matrix[1][2])

# %% [markdown]
# ### Kategoryzacja punktu względem prostej

# %%
def categorize_point(a,b,c,eps=10**(-8)): #(wspolrzedne a, wspolrzedne b, wspolrzedne c, tolerancja dla zera)
    temp=det(a,b,c)
    if abs(temp) < eps:
        return "collinear"
    elif temp > 0:
        return "left"
    else:
        return "right"

# %% [markdown]
# ### Odległość pomiędzy punktami

# %%
def d(a,b):
    return np.sqrt((b[0]-a[0])**2+(b[1]-a[1])**2)

# %% [markdown]
# ### Wyszukiwanie punktu o najmniejszej współrzędnej y

# %%
def min_y(X):
    res=X[0]
    for i in range(1,len(X)):
        if res[1]>X[i][1] or (res[1]==X[i][1] and res[0]<X[i][0]):
            res=X[i]    
    return res

# %% [markdown]
# ### Sortowanie punktów - zmodyfikowany quicksort

# %%
def partition(T,low,high,a):
    pivot=T[high]
    i=low-1
    for j in range(low,high):
        temp=categorize_point(a,pivot,T[j])
        if temp=="right":
            i+=1
            T[i],T[j]=T[j],T[i]
        elif temp=="collinear":
            if d(a,pivot)<d(a,T[j]):
                i+=1
                T[i],T[j]=T[j],T[i]  
    T[high],T[i+1]=T[i+1],T[high]
    return i+1

def quicksort(T,low,high,a):
    if low<high:
        q=partition(T,low,high,a)
        quicksort(T,low,q-1,a)
        quicksort(T,q+1,high,a)

# %% [markdown]
# ### Utworzenie zbioru linii ze zbioru punktów

# %%
def points_to_lines(X):
    res=[]
    for i in range(len(X)-1):
        res.append([(X[i]),(X[i+1])])
    return res

# %% [markdown]
# ### Zapis do pliku

# %%
def save_res(result,filepath):
    f=open(filepath,"w")
    s=[str(result[i]) for i in range(len(result))]
    s=" ".join(s)
    f.write("WYNIK: "+s)
    f.close()

# %% [markdown]
# ### Wyświetlanie i zapis wyników

# %%
def show_res(X,f,filepath=""): # (zbiór X, funkcja algorytmu (graham_svis lub jarvis_svis), *jeżeli zapis do pliku* sciezka pliku)
    res=f(X)
    print("Liczebność punktów w otoczce:",len(res[0]))
    print("Czas wykonania:", "%.5f" % res[1])
    if filepath:
        save_res(res[0],filepath)
    res[2].draw()

# %% [markdown]
# # ALGORYTM GRAHAMA

# %% [markdown]
# ## Implementacja algorytmu Grahama

# %% [markdown]
# ### Wersja bez wizualizacji

# %%
def graham(X): # (zbiór punktów)
    a=min_y(X)
    quicksort(X,0,len(X)-1,a)
    hull=[a,X[0]]
    for i in range(1,len(X)):
        while len(hull)>1 and categorize_point(hull[-2],hull[-1],X[i])!="left":
            hull.pop()
        hull.append(X[i])
    hull.pop()
    return hull

# %% [markdown]
# ### Wersja z wizualizacją statyczną

# %%
def graham_svis(X): # (zbiór punktów)
    time0=time()
    a=min_y(X)
    quicksort(X,0,len(X)-1,a)
    hull=[a,X[0]]
    for i in range(1,len(X)):
        while len(hull)>1 and categorize_point(hull[-2],hull[-1],X[i])!="left":
            hull.pop()
        hull.append(X[i])
    time1=time()
    plot=Plot(points=[PointsCollection(X,color="khaki"), PointsCollection(hull,color="darkgreen",marker="D")], lines=[LinesCollection(points_to_lines(hull), color='limegreen')])
    hull.pop()
    return hull,time1-time0,plot

# %% [markdown]
# ### Wersja z wizualizacją dynamiczną

# %%
def graham_dvis(X): # (zbiór punktów)
    a=min_y(X)
    quicksort(X,0,len(X)-1,a)
    hull=[a,X[0]]
    scenes=[]
    for i in range(1,len(X)):
        scenes.append(Scene([PointsCollection(X)], [LinesCollection(points_to_lines(hull[0:-1]), color='limegreen'), LinesCollection(points_to_lines(hull[-1:-3:-1]), color='orange')]))
        while len(hull)>1 and categorize_point(hull[-2],hull[-1],X[i])!="left":
            scenes.append(Scene([PointsCollection(X)], [LinesCollection(points_to_lines(hull[0:-1]), color='limegreen'), LinesCollection(points_to_lines(hull[-1:-3:-1]), color='orange'), LinesCollection([[hull[-1],X[i]]], color='red')]))
            hull.pop()
        hull.append(X[i])
    scenes.append(Scene([PointsCollection(X)], [LinesCollection(points_to_lines(hull[0:-1]), color='limegreen'), LinesCollection(points_to_lines(hull[-1:-3:-1]), color='orange')]))
    scenes.append(Scene([PointsCollection(X,color="khaki"), PointsCollection(hull,color="darkgreen",marker="D")], [LinesCollection(points_to_lines(hull), color='limegreen')]))
    return scenes

# %% [markdown]
# ## Wizualizacja przebiegu algorytmu Grahama

# %%
# %matplotlib notebook
plot=Plot(scenes=graham_dvis(D))
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Algorytm Grahama dla zestawów A-D

# %% [markdown]
# ### Zestaw A

# %%
# %matplotlib notebook
show_res(A,graham_svis,"results.txt")
# Out:
# Liczebność punktów w otoczce: 12
# Czas wykonania: 0.00199
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw B

# %%
# %matplotlib notebook
show_res(B,graham_svis,"results.txt")
# Out:
# Liczebność punktów w otoczce: 100
# Czas wykonania: 0.00302
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw C

# %%
# %matplotlib notebook
show_res(C,graham_svis,"results.txt")
# Out:
# Liczebność punktów w otoczce: 8
# Czas wykonania: 0.00099
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw D

# %%
# %matplotlib notebook
show_res(D,graham_svis,"results.txt")
# Out:
# Liczebność punktów w otoczce: 4
# Czas wykonania: 0.01000
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Algorytm Grahama dla zmodyfikowanych zestawów A-D

# %% [markdown]
# ### Zestaw A_mod

# %%
# %matplotlib notebook
show_res(A_mod,graham_svis)
# Out:
# Liczebność punktów w otoczce: 31
# Czas wykonania: 2.43855
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw B_mod

# %%
# %matplotlib notebook
show_res(B_mod,graham_svis)
# Out:
# Liczebność punktów w otoczce: 3000
# Czas wykonania: 2.49433
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw C_mod

# %%
# %matplotlib notebook
show_res(C_mod,graham_svis)
# Out:
# Liczebność punktów w otoczce: 8
# Czas wykonania: 3.87765
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw D_mod

# %%
# %matplotlib notebook
show_res(D_mod,graham_svis)
# Out:
# Liczebność punktów w otoczce: 4
# Czas wykonania: 1.85902
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # ALGORYTM JARVISA

# %% [markdown]
# ## Implementacja algorytmu Jarvisa

# %% [markdown]
# ### Wersja bez wizualizacji

# %%
def jarvis(X):
    on_hull=min_y(X)
    hull=[]
    while True:
        hull.append(on_hull)
        next_point=X[0]
        for p in X:
            o=categorize_point(on_hull,next_point,p)
            if next_point==on_hull or o=="right" or (o=="collinear" and d(on_hull, next_point)<d(on_hull, p)):
                next_point=p
        on_hull=next_point
        if on_hull==hull[0]:
            break
    return hull

# %% [markdown]
# ### Wersja z wizualizacją statyczną

# %%
def jarvis_svis(X):
    time0=time()
    on_hull=min_y(X)
    hull=[]
    while True:
        hull.append(on_hull)
        next_point=X[0]
        for p in X:
            o=categorize_point(on_hull,next_point,p)
            if next_point==on_hull or o=="right" or (o=="collinear" and d(on_hull, next_point)<d(on_hull, p)):
                next_point=p
        on_hull=next_point
        if on_hull==hull[0]:
            break
    time1=time()
    hull.append(on_hull)
    plot=Plot(points=[PointsCollection(X,color="khaki"), PointsCollection(hull,color="darkgreen",marker="D")], lines=[LinesCollection(points_to_lines(hull), color='limegreen')])
    hull.pop()
    return hull,round(time1-time0,5),plot

# %% [markdown]
# ### Wersja z wizualizacją dynamiczną

# %%
def jarvis_dvis(X):
    on_hull=min_y(X)
    hull=[]
    scenes=[]
    
    while True:
        hull.append(on_hull)
        next_point=X[0]
        if next_point==on_hull:
            next_point=X[1]
        scenes.append(Scene([PointsCollection(X)], [LinesCollection(points_to_lines(hull), color='limegreen')]))                  
        for p in X:
            o=categorize_point(on_hull,next_point,p)
            scenes.append(Scene([PointsCollection(X)], [LinesCollection(points_to_lines(hull), color='limegreen'), LinesCollection(points_to_lines([on_hull,next_point]), color='orange'), LinesCollection(points_to_lines([p,next_point]), color='khaki')]))                  
            if next_point==on_hull or o=="right" or (o=="collinear" and d(on_hull, next_point)<d(on_hull, p)):
                scenes.append(Scene([PointsCollection(X)], [LinesCollection(points_to_lines(hull), color='limegreen'), LinesCollection(points_to_lines([on_hull,next_point]), color='red'), LinesCollection(points_to_lines([p,next_point]), color='khaki')]))                  
                next_point=p
                scenes.append(Scene([PointsCollection(X)], [LinesCollection(points_to_lines(hull), color='limegreen'), LinesCollection(points_to_lines([on_hull,next_point]), color='orange')]))                         
        on_hull=next_point
        if on_hull==hull[0]:
            hull.append(on_hull)
            scenes.append(Scene([PointsCollection(X,color="khaki"), PointsCollection(hull,color="darkgreen",marker="D")], [LinesCollection(points_to_lines(hull), color='limegreen')]))
            break
    return scenes

# %% [markdown]
# ## Wizualizacja przebiegu algorytmu Jarvisa

# %%
# %matplotlib notebook
plot=Plot(scenes=jarvis_dvis(D))
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Algorytm Jarvisa dla zestawów A-D

# %% [markdown]
# ### Zestaw A

# %%
# %matplotlib notebook
show_res(A,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 12
# Czas wykonania: 0.00199
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw B

# %%
# %matplotlib notebook
show_res(B,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 100
# Czas wykonania: 0.02290
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw C

# %%
# %matplotlib notebook
show_res(C,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 8
# Czas wykonania: 0.00202
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw D

# %%
# %matplotlib notebook
show_res(D,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 4
# Czas wykonania: 0.00100
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Algorytm Jarvisa dla zmodyfikowanych zestawów A-D

# %% [markdown]
# ### Zestaw A_mod

# %%
# %matplotlib notebook
show_res(A_mod,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 31
# Czas wykonania: 3.68716
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw B_mod (UWAGA - długi czas obliczeń)

# %%
# %matplotlib notebook
show_res(B_mod,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 3000
# Czas wykonania: 19.75317
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw C_mod

# %%
# %matplotlib notebook
show_res(C_mod,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 8
# Czas wykonania: 1.37933
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Zestaw D_mod

# %%
# %matplotlib notebook
show_res(D_mod,jarvis_svis)
# Out:
# Liczebność punktów w otoczce: 4
# Czas wykonania: 0.30518
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Graham vs Jarvis - porównanie czasów obliczeń

# %%
def test(x):
    for i in range(len(x)):
        g=graham_svis(x[i])[1]
        j=jarvis_svis(x[i])[1]
        print("#"+str(i+1)+"\tGraham: "+str("%.5f" % g)+"\t\tJarvis: "+str("%.5f" % j))

# %% [markdown]
# ### Test 1

# %%
test((A,B,C,D)) # 100 100 100 90
# Out:
# #1	Graham: 0.00602		Jarvis: 0.00099
# #2	Graham: 0.01097		Jarvis: 0.02294
# #3	Graham: 0.00699		Jarvis: 0.00099
# #4	Graham: 0.00698		Jarvis: 0.00000

# %% [markdown]
# ### Test 2

# %%
a_1=gen_A(10**3,-10**3,10**3,123) # 1000 
b_1=gen_B(3*10**2,(-20,134),100,10234) #300
c_1=gen_C(10**3,(-536,-120),(1045,102),11) # 1000
d_1=gen_D(10**2,10**2,(-240,-126),(2354,855),10) # 400

test((a_1,b_1,c_1,d_1))
# Out:
# #1	Graham: 0.01696		Jarvis: 0.01596
# #2	Graham: 0.02593		Jarvis: 0.19645
# #3	Graham: 0.02197		Jarvis: 0.01194
# #4	Graham: 0.00997		Jarvis: 0.00199

# %% [markdown]
# ### Test 3

# %%
a_2=gen_A(5*10**4,-10**3,10**3,123) # 50000
b_2=gen_B(5*10**2,(-20,134),100,10234) # 500
c_2=gen_C(10**4,(-536,-120),(1045,102),11) # 10000
d_2=gen_D(10**3,10**3,(-240,-126),(2354,855),10) # 4000

test((a_2,b_2,c_2,d_2))
# Out:
# #1	Graham: 1.24367		Jarvis: 1.51595
# #2	Graham: 0.07184		Jarvis: 0.55748
# #3	Graham: 0.30020		Jarvis: 0.12467
# #4	Graham: 0.14860		Jarvis: 0.02892

# %% [markdown]
# ### Test 4

# %%
a_3=gen_A(10**5,-10**3,10**3,123) # 100000
b_3=gen_B(10**3,(-20,134),100,10234) # 1000
c_3=gen_C(10**5,(-536,-120),(1045,102),11) # 100000
d_3=gen_D(10**4,10**4,(-240,-126),(2354,855),10) # 40000

test((a_3,b_3,c_3,d_3))
# Out:
# #1	Graham: 2.46151		Jarvis: 3.78784
# #2	Graham: 0.27925		Jarvis: 2.17418
# #3	Graham: 3.95142		Jarvis: 1.38529
# #4	Graham: 1.91388		Jarvis: 0.32313

# %% [markdown]
# ### Test 5 (UWAGA - długi czas obliczeń)

# %%
a_4=gen_A(2*10**5,-10**3,10**3,123) # 200000
b_4=gen_B(2*10**3,(-20,134),100,10234) # 2000
c_4=gen_C(2*10**5,(-536,-120),(1045,102),11) # 200000
d_4=gen_D(2*10**4,2*10**4,(-240,-126),(2354,855),10) # 80000

test((a_4,b_4,c_4,d_4))
# Out:
# #1	Graham: 5.47136		Jarvis: 8.51119
# #2	Graham: 1.13097		Jarvis: 8.79250
# #3	Graham: 8.18416		Jarvis: 2.72870
# #4	Graham: 3.88166		Jarvis: 0.61735

# %% [markdown]
# ### Test 6 (UWAGA - długi czas obliczeń)

# %%
a_6=gen_A(3*10**5,-10**3,10**3,123) # 300000
b_6=gen_B(3*10**3,(-20,134),100,10234) # 3000
c_6=gen_C(3*10**5,(-536,-120),(1045,102),11) # 300000
d_6=gen_D(3*10**4,3*10**4,(-240,-126),(2354,855),10) # 120000

test((a_6,b_6,c_6,d_6))
# Out:
# #1	Graham: 8.68778		Jarvis: 12.62322
# #2	Graham: 2.51526		Jarvis: 19.74137
# #3	Graham: 12.94838		Jarvis: 4.09410
# #4	Graham: 6.26327		Jarvis: 0.94846
